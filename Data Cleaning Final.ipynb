# %%
# pandas to work with dataframes
import pandas as pd
# import re to use regular expressions
import re
# import numpy
import numpy as np
# import glob to bring together multiple csv files
import glob

# search for csvs containing web-scraped data with the name scheme
csvs = glob.glob(r'*Craigslist_ApartmentData_Minneapolis*.csv')

# set dfs list to store each dataframe that gets read in
dfs = []

# iterate through csv files gathered in glob
for file in csvs:
    # read each csv as a dataframe with the same column names
    df1 = pd.read_csv(file, names=['address', 'square feet', 'beds_baths', 'datetime', 'square feet 2', 'latitude', 'title', 'longitude', 'map accuracy', 'price', 'url', 'post id'])
    # append dataframe to dfs list
    dfs.append(df1)

# concatenate dataframes in dfs together vertically
df = pd.concat(dfs, axis=0)
# set an index of integers equal to the length of dataframe rows
index_list = list(range(len(df.index)))
# make index series a column in dataframe
df['index'] = index_list
# set index column as index of dataframe
df = df.set_index(['index'])

# set entire df type as string, as most operations will require data type to be string
df = df.astype(str)

# drop any post id values that are null
postid_no_null = df.dropna(subset = ['post id'])



# create dataframe where "post id" column is null
null_id = df[df['post id'].isnull()]
# drop duplicates in null_id dataframe using the "title" column
null_id = null_id.drop_duplicates(subset=['title'], keep='first')
# drop duplicates using "post id" column in the dataframe containing no null "post id" values
postid_no_null = df.drop_duplicates(subset=['post id'], keep='first')
# concatenate vertically null_id and postid_no_null dataframes
df = pd.concat([null_id, postid_no_null])
# drop latitude, longitude, map accuracy columns 
df = df.drop(columns=['latitude', 'longitude', 'map accuracy'])


# extract and store all possible valid square feet or beds values across columns where they might be
# using findall function

# column to store values of square feet that exist in column
df['value_square_feet_two'] = [re.findall('\d+ft', str(cell)) for cell in df['square feet 2']]
# create column of all patterns of square feet that exist in  beds_baths column
df['value_square_feet_three'] = [re.findall('\d+ft', str(cell)) for cell in df['beds_baths']]
# get all patterns of beds that exist in "square feet 2" column
df['number_of_beds_2'] = [re.findall('\d+br', str(cell)) for cell in df['square feet 2']]
# clean values from columns to prepare them to be brought into "square feet", "price" and "beds_baths" columns
df['number_of_beds_2'] = df['number_of_beds_2'].astype(str)
df['value_square_feet_two'] = df['value_square_feet_two'].astype(str)
df['value_square_feet_three'] = df['value_square_feet_three'].astype(str)

# create a boolean of whether or not a beds/bath pattern exists in the "beds_baths" column
df['first_beds_boolean'] = [bool(re.search('\d+[Bb]', cell)) for cell in df['beds_baths']] 
# get boolean of whether or not beds value is present in "square feet 2" column
df['second_beds_boolean'] = [bool(re.search('\d+br', str(cell))) for cell in df['square feet 2']]
# clean value before moving
df.loc[df['second_beds_boolean'] == 1, 'number_of_beds_2'] = df['number_of_beds_2'].apply(lambda x: str(x[2:-2]))
# where value in "beds_baths" is not available, and is available in "square feet 2", 
# fill with the beds value of "square feet 2", stored in "number_of_beds_2"
df.loc[(df['second_beds_boolean'] == 1) & (df['first_beds_boolean'] == 0), 'beds_baths'] = df['number_of_beds_2']
# create a boolean of whether or not a square feet pattern exists in the "square feet" column
df['first_square_feet_boolean'] = [bool(re.search('\d+ft', str(cell))) for cell in df['square feet']]
# boolean to see if row in square feet 2 column contains square feet value
df['second_square_feet_boolean'] = [bool(re.search('\d+ft', str(cell))) for cell in df['square feet 2']]
# clean value before moving
df.loc[df['second_square_feet_boolean'] == 1, 'value_square_feet_two'] = df['value_square_feet_two'].apply(lambda x: str(x[2:-2]))
# where value in "square feet" is not available, and is available in "square feet 2", 
# fill with the square feet value of "square feet 2", stored in "value_square_feet_two"
df.loc[(df['first_square_feet_boolean'] == 0) & (df['second_square_feet_boolean'] == 1), 'square feet'] = df['value_square_feet_two']
# boolean to see if beds_baths column is True/False for square feet pattern
df['third_square_feet_boolean'] = [bool(re.search('\d+ft', str(cell))) for cell in df['beds_baths']]
# clean value before moving
df.loc[df['third_square_feet_boolean'] == 1, 'value_square_feet_three'] = df['value_square_feet_three'].apply(lambda x: str(x[2:-2]))
# for all values in beds_bath where the square feet pattern is true, 
# cell value is updated with number in square_feet_one
df.loc[(df['first_square_feet_boolean'] == 0) & (df['second_square_feet_boolean'] == 0) & (df['third_square_feet_boolean'] == 1), 'square feet'] = df['value_square_feet_three']
# for square feet, beds_baths and price columns, determine if appropriate values are present with boolean
# in order to fill these columns with appropriate values in future operations
df['square feet boolean'] = [bool(re.search('\d+ft', str(cell))) for cell in df['square feet']]
df['beds boolean'] = [bool(re.search('\d+[Bb]', str(cell))) for cell in df['beds_baths']]
df['price boolean'] = [bool(re.search('\d+', str(cell))) for cell in df['price']]


# get just digits in square feet column 
df.loc[(df['square feet boolean'] == 1), 'square feet'] = df['square feet'].apply(lambda x: x[0:-3])
# get just numerical value of beds_baths
df.loc[df['beds_baths'].str.contains(r'B'), 'beds_baths'] = df['beds_baths'].apply(lambda x: x[0])
# get just price in "price" column
df['price'] = df.price.apply(lambda x: x.replace('$', ''))
# identify and drop posts associated with the superbowl
df['check_superbowl'] = [bool(re.search("SUPERBOWL|Superbowl|SUPER BOWL|Super bowl|superbowl|super bowl|Super Bowl", cell)) for cell in df['title']]
df = df.drop(df[df['check_superbowl'] == 1].index)
# check "address" column to see if address exists and create boolean value in "address_check" column
df['address_check'] = [bool(re.search('\d.*|\b.*', str(cell))) for cell in df['address']]
# extract url information from "url" column and fill as value in "county" column
df['county'] = [str(re.findall('org/.../', cell))[6:9] for cell in df['url']]


# get latitude and longitude of counties and assign to respective "county_lat" and "county_lon" coordinates

# create county_lat, county_lon columns
df['address_lat'] = df['county']
df['address_lon'] = df['county']


# make this shorter with a function 
#counties_list = [hnp, wsh, ram, dak, csw, ank]
#counties_lat_lon = {"hnp" : ["45.0209", "-93.5095"], "wsh" : ["44.8897", "-92.8577"], "ram" : ["44.9964", "-93.0616"], "dak" : ["44.7316", "-93.1780"], "csw" : ["44.8254", "-93.7842"]  "ank" : ["45.1977428", "-93.3871758"]}
#hennepin county
df.loc[(df['county'] == "hnp") & (df['address_check'] == False), 'county_lat' ] = "45.0209"
df.loc[(df['county'] == "hnp") & (df['address_check'] == False), 'county_lon' ] = "-93.5095"

#washington county
df.loc[(df['county'] == "wsh") & (df['address_check'] == False), 'county_lat' ] = "44.8897"
df.loc[(df['county'] == "wsh") & (df['address_check'] == False), 'county_lon' ] = "-92.8577"

# ramsey county
df.loc[(df['county'] == "ram") & (df['address_check'] == False), 'county_lat' ] = "44.9964"
df.loc[(df['county'] == "ram") & (df['address_check'] == False), 'county_lon' ] = "-93.0616"

# dakota county
df.loc[(df['county'] == "dak") & (df['address_check'] == False), 'county_lat' ] = "44.7316"
df.loc[(df['county'] == "dak") & (df['address_check'] == False), 'county_lon' ] = "-93.1780"


# scott, carver, wright
df.loc[(df['county'] == "csw") & (df['address_check'] == False), 'county_lat' ] = "44.8254"
df.loc[(df['county'] == "csw") & (df['address_check'] == False), 'county_lon' ] = "-93.7842"

# anoka
df.loc[(df['county'] == "ank") & (df['address_check'] == False), 'county_lat' ] = "45.1977428"
df.loc[(df['county'] == "ank") & (df['address_check'] == False), 'county_lon' ] = "-93.3871758"

# create a column county_state with county and state to append to each respective address
df['county_state'] = df['county']
df.loc[(df['county'] == "hnp"), "county_state"] = " ,Hennepin County, Minnesota"
df.loc[(df['county'] == "ram"), "county_state"] = " ,Ramsey County, Minnesota"
df.loc[(df['county'] == "dak"), "county_state"] = " ,Dakota County, Minnesota"
df.loc[(df['county'] == "ank"), "county_state"] = " ,Anoka County, Minnesota"
df.loc[(df['county'] == "wsh"), "county_state"] = " ,Washington County, Minnesota"
df.loc[(df['county'] == "csw"), "county_state"] = " ,Carver County, Minnesota"
# append the value in county_state to each respective address
df.loc[(df['address_check'] == True), 'address'] = df[['address', 'county_state']].apply(''.join, axis=1)
# create geocode_lat and geocode_lon columns for geocoding
df['geocode_lat'] = "none"
df['geocode_lon'] = "none"

# save dataframe without missing addresses to be geocoded
# then resume script after values have been geocoded

df.to_csv('geocode_craigslist_rentals_2')
# Out:
#                                                  address square feet  \
# index
# 0                                                    nan     1046.67
# 1      4th Street NE at 23rd Ave ,Hennepin County, Mi...     1046.67
# 2                                                    nan     1046.67
# 3      6426 City West Parkway  ,Hennepin County, Minn...         688
# 4                                                    nan     1046.67
# 5                                                    nan     1046.67
# 6                                                    nan     1046.67
# 7                                                    nan     1046.67
# 8      Aldrich Ave S at W 26th St ,Hennepin County, M...         950
# 9                                                    nan     1046.67
# 10      2922 Aldrich Ave. S. ,Hennepin County, Minnesota         789
# 11        2837 Emerson Ave S ,Hennepin County, Minnesota        1528
# 12           7617 Knox Ave S ,Hennepin County, Minnesota         720
# 13        700 Douglas Avenue ,Hennepin County, Minnesota         800
# 14     27 West 27th Street at 27th and Blaisdell ,Hen...         650
# 15     Chicago Ave at 55th St E ,Hennepin County, Min...        1200
# 16            808 Berry Street ,Ramsey County, Minnesota        1181
# 17                                                   nan     1046.67
# 18                                                   nan     1046.67
# 19                                                   nan     1046.67
# 20     10275 Greenbrier Road  ,Hennepin County, Minne...        1120
# 21     10225 City Walk Drive ,Washington County, Minn...         849
# 22                                                   nan         696
# 23                                                   nan     1046.67
# 24     129 North 2nd Street  ,Hennepin County, Minnesota         980
# 25                                   OAK GROVE at SPRUCE     1046.67
# 26     2904 Lyndale Ave South ,Hennepin County, Minne...         820
# 27     2838 Fremont Avenue South ,Hennepin County, Mi...         739
# 28        Hennepin at 1st st ,Hennepin County, Minnesota        1580
# 29        2904 Lyndale Ave S ,Hennepin County, Minnesota         541
# ...                                                  ...         ...
# 77286             2620 9th Lane ,Anoka County, Minnesota         575
# 77288     8524 Xenium Lane N ,Hennepin County, Minnesota        1588
# 77289   10120 Lyndale Circle ,Hennepin County, Minnesota         970
# 77290    172 East Sixth Street ,Ramsey County, Minnesota         849
# 77292    12300 SINGLETREE LN ,Hennepin County, Minnesota        1012
# 77293         2620 9th lane 301 ,Anoka County, Minnesota        1000
# 77294   14550 34th Ave North ,Hennepin County, Minnesota        1308
# 77295  2410 University Avenue West ,Ramsey County, Mi...         662
# 77296     4379 Wilshire Blvd ,Hennepin County, Minnesota         900
# 77297      1180 Cushing Circle ,Ramsey County, Minnesota        1193
# 77299                                                nan     1046.67
# 77300  337 Washington Avenue North ,Hennepin County, ...         700
# 77301                                                nan         847
# 77304          1417 10th St NW ,Ramsey County, Minnesota         780
# 77307  1020 W. Medicine Lake Drive ,Hennepin County, ...         517
# 77308          1417 10th St NW ,Ramsey County, Minnesota         915
# 77309         1120 52nd Ave NE ,Ramsey County, Minnesota     1046.67
# 77310                                                nan     1046.67
# 77311         3036 W Lake St ,Hennepin County, Minnesota         700
# 77312                                                nan     1046.67
# 77315      201 W.96th Street ,Hennepin County, Minnesota         700
# 77318  5th st N at 6th ave N ,Hennepin County, Minnesota         805
# 77320      201 W.96th Street ,Hennepin County, Minnesota         700
# 77326  401 8th Avenue in Isanti at County Road 5 and ...        1019
# 77329  15100 18th Ave N at Niagara ,Hennepin County, ...        1000
# 77330                                                nan         600
# 77331        2740 9th Lane, 307 ,Anoka County, Minnesota         800
# 77333  15100 18th Ave N at Niagara ,Hennepin County, ...         910
# 77457                                   SPRUCE at HARMON     1046.67
# 77458                                  Apgar at Shakopee        1600
#
#       beds_baths                  datetime       square feet 2  \
# index
# 0              2  2018-01-13T20:02:24-0600            / 2br -
# 1              1  2018-01-11T17:04:47-0600            / 1br -
# 2              1  2018-01-13T20:00:35-0600            / 1br -
# 3              1  2017-12-23T11:08:11-0600   / 1br - 688ft2 -
# 4              1  2018-01-13T19:59:36-0600            / 1br -
# 5              1  2018-01-13T19:58:35-0600            / 1br -
# 6              1  2018-01-13T19:54:57-0600            / 1br -
# 7              1  2018-01-13T19:53:37-0600            / 1br -
# 8              2  2018-01-15T11:45:55-0600   / 2br - 950ft2 -
# 9            1.7  2018-01-18T18:31:08-0600                 nan
# 10             1  2018-01-18T17:56:59-0600   / 1br - 789ft2 -
# 11             2  2018-01-18T18:28:45-0600  / 2br - 1528ft2 -
# 12             1  2018-01-18T17:27:13-0600   / 1br - 720ft2 -
# 13             1  2018-01-18T18:13:46-0600   / 1br - 800ft2 -
# 14             1  2018-01-18T18:23:31-0600   / 1br - 650ft2 -
# 15             2  2018-01-14T10:41:14-0600  / 2br - 1200ft2 -
# 16             2  2018-01-18T18:21:05-0600  / 2br - 1181ft2 -
# 17             1  2018-01-12T10:59:53-0600            / 1br -
# 18             1  2018-01-18T18:20:17-0600            / 1br -
# 19             1  2018-01-18T18:15:09-0600            / 1br -
# 20             2  2018-01-04T08:51:30-0600  / 2br - 1120ft2 -
# 21             1  2018-01-18T18:05:15-0600   / 1br - 849ft2 -
# 22             1  2018-01-18T18:17:54-0600   / 1br - 696ft2 -
# 23             2  2018-01-18T17:19:10-0600            / 2br -
# 24             2  2018-01-12T16:17:32-0600   / 2br - 980ft2 -
# 25             1  2018-01-18T18:15:25-0600            / 1br -
# 26             1  2018-01-18T18:14:08-0600   / 1br - 820ft2 -
# 27             1  2018-01-18T17:39:14-0600   / 1br - 739ft2 -
# 28             2  2018-01-18T18:12:53-0600  / 2br - 1580ft2 -
# 29             0  2018-01-18T18:12:43-0600         / 541ft2 -
# ...          ...                       ...                 ...
# 77286          0  2018-03-08T16:04:40-0600         / 575ft2 -
# 77288          3  2018-03-08T16:03:53-0600  / 3br - 1588ft2 -
# 77289          2  2018-03-08T15:55:58-0600   / 2br - 970ft2 -
# 77290          1  2018-03-08T16:02:15-0600   / 1br - 849ft2 -
# 77292          1  2018-03-06T15:38:12-0600  / 1br - 1012ft2 -
# 77293          2  2018-03-08T15:59:34-0600  / 2br - 1000ft2 -
# 77294          2  2018-03-08T15:59:25-0600  / 2br - 1308ft2 -
# 77295          1  2018-03-08T15:59:11-0600   / 1br - 662ft2 -
# 77296          1  2018-03-08T15:58:46-0600   / 1br - 900ft2 -
# 77297          2  2018-03-08T15:56:33-0600  / 2br - 1193ft2 -
# 77299          3  2018-03-08T14:52:59-0600            / 3br -
# 77300          1  2018-03-08T15:53:11-0600   / 1br - 700ft2 -
# 77301          1  2018-03-08T15:53:11-0600   / 1br - 847ft2 -
# 77304          2  2018-03-08T15:51:44-0600   / 2br - 780ft2 -
# 77307          0  2018-03-08T15:51:02-0600         / 517ft2 -
# 77308          2  2018-03-08T15:50:41-0600   / 2br - 915ft2 -
# 77309          2  2018-03-08T15:49:30-0600            / 2br -
# 77310          2  2018-03-08T15:29:19-0600            / 2br -
# 77311          1  2018-03-08T15:49:13-0600   / 1br - 700ft2 -
# 77312          2  2018-03-08T15:47:23-0600            / 2br -
# 77315          1  2018-03-08T15:41:40-0600   / 1br - 700ft2 -
# 77318          1  2018-03-08T15:40:28-0600   / 1br - 805ft2 -
# 77320          1  2018-03-08T15:39:45-0600   / 1br - 700ft2 -
# 77326          2  2018-03-08T15:37:49-0600  / 2br - 1019ft2 -
# 77329          2  2018-03-08T15:35:48-0600  / 2br - 1000ft2 -
# 77330          1  2018-03-08T15:12:07-0600   / 1br - 600ft2 -
# 77331          1  2018-03-08T15:34:24-0600   / 1br - 800ft2 -
# 77333          1  2018-03-08T15:33:33-0600   / 1br - 910ft2 -
# 77457          2  2018-03-08T14:29:21-0600            / 2br -
# 77458          3  2018-03-08T14:29:10-0600  / 3br - 1600ft2 -
#
#                                                    title  price  \
# index
# 0      Be Part Of Uptown - The Lake/Calhoun Square/Th...   1975
# 1      Upstairs 1 BR duplex unit, highly walkable in ...   1150
# 2      North Loop Luxury One Bed - 1 Block From Skywa...   1600
# 3          Very cozy apartment with beautiful woods view   1223
# 4      Live On The Park! Must See Unit w/Heated Parki...   2045
# 5      Loring Park Studio w/Amazing Amenties - Gym, G...   1680
# 6         Insane Poolside Amenities in this Uptown Pad!!   1385
# 7      Great 1 Bed Value Just Steps Away From Britt's...   1405
# 8                   Uptown 2bdr/1bth, Wedge Neighborhood   1500
# 9                   Frunished 1 bedroom 1 bathroom condo   1800
# 10            Fully Furnished One Bedroom Available Now!   2800
# 11     Townhome with attached 2 car garage! Luxury am...   2652
# 12                    One Month FREE with 12 Month Lease   1160
# 13     Near Everywhere You Want To Be! Heat & Parking...   1385
# 14      Lovely 1 bedroom in arts building in trendy area    775
# 15     • Sharp Sunny 2-Story Double Bungalow...Owner ...   1100
# 16     Beautiful 2 BR 2 BA W/ Balcony & Free Parking!...   1643
# 17                       Private 1 bedroom country house    925
# 18     Along Light Rail -Washer/Dryer in each unit 1 ...   1490
# 19     PETS WELCOME! -NEW BUILDING- IMMEDIATE MOVE IN...   1490
# 20     3 Bedroom Available for Immediate Move In!  Gr...   1410
# 21                Sauna, Golf simulator, Walk-in closets   1396
# 22     1BR - Granite, South facing view, Minutes to U...   1416
# 23     OD pool with sundeck, Elevators in 1 building ...   1270
# 24     Heated Underground Parking, Elevator, High Cei...   1980
# 25     ****1 BED W/HARDWOOD FLRS AVAIL BY LORING PARK...    929
# 26            1MONTH FREE RENT AND 3MONTHS FREE PARKING!   1599
# 27                               Biggest Pool In Uptown!   1675
# 28     Newly constructed town home available now thro...   3995
# 29        Check out this AWESOME alcove today! Call now!   1415
# ...                                                  ...    ...
# 77286                   RARE STUDIO PLUS ELECTRIC 20-108    700
# 77288  ✪ Fabulous Maple Grove Location! 3 Bed 3 Bath ...   1595
# 77289  Walk-in closet, Dining area, Refrigerator, Sto...   1195
# 77290                    Where Convenience Meets Luxury.   1365
# 77292  Business Center, Public Transportation, Packag...   1445
# 77293      COME CHECK OUT OUR WONDERFUL COMMUNITY 20-301   1035
# 77294          Newly Updated Units! Call Now for a Tour!   1610
# 77295  Change Your World. Expand Your Horizons. Live ...   1495
# 77296                  Lake Minnetonka, Spring Park Bay!    995
# 77297  Brand New Never Lived In Apartment Homes !! Co...   1798
# 77299  ♯ /renttoown/! AWESOME MASTER BDRM & BATH*ROOM...    400
# 77300  $1000 OFF first Months Reny If Applied by 3/11/18   1635
# 77301    Call for Details, On Bus Route, Gated Community    790
# 77304  Two Bedroom For Rent @ Garden View Apartments!...    895
# 77307  Your Keys To A New Beginning At Stone Creek! T...   1175
# 77308  Two Bedroom For Rent @ Garden View Apartments!...    945
# 77309  Two Bedroom For Rent @ South Fridley Apartment...    865
# 77310       Coming soon, updated Lakewood unit for rent!    500
# 77311  Home is where the "heart of Uptown" is. Alcove...   1524
# 77312              Seniors! No need to look any further!    955
# 77315                                Top Floor= Peaceful   1015
# 77318  Top Floor, Corner Unit 1BR w/ 3 Months FREE Pa...   1624
# 77320    Spacious and Sunny One Bedroom Coming Available   1015
# 77326   Call to be placed on our preferred contact list!   1250
# 77329            2 Bedroom 1 Bath - Renovated- Park View   1566
# 77330  1 bdrm 1st Floor end unit Senior Community (50...    775
# 77331  LETS TALK A CHANGE IN YOUR LIVING SITUATION 4/...    825
# 77333           1 Bedroom Available for a March Move In!   1144
# 77457  ****2 BEDROOM NEAR LORING PARK W/HRD WD FLRS. ...   1160
# 77458                  Shakopee!  3 Bedroom  W/D in unit   1520
#
#                                                      url              post id  \
# index
# 0      https://minneapolis.craigslist.org/hnp/apa/d/b...  post id: 6458930089
# 1      https://minneapolis.craigslist.org/hnp/apa/d/u...  post id: 6456393172
# 2      https://minneapolis.craigslist.org/hnp/apa/d/n...  post id: 6458928789
# 3      https://minneapolis.craigslist.org/hnp/apa/d/v...  post id: 6435935112
# 4      https://minneapolis.craigslist.org/hnp/apa/d/l...  post id: 6458928087
# 5      https://minneapolis.craigslist.org/hnp/apa/d/l...  post id: 6458927342
# 6      https://minneapolis.craigslist.org/hnp/apa/d/i...  post id: 6458924686
# 7      https://minneapolis.craigslist.org/hnp/apa/d/g...  post id: 6458923708
# 8      https://minneapolis.craigslist.org/hnp/apa/d/u...  post id: 6460540386
# 9      https://minneapolis.craigslist.org/wsh/apa/d/f...  post id: 6464729986
# 10     https://minneapolis.craigslist.org/hnp/apa/d/f...  post id: 6464697028
# 11     https://minneapolis.craigslist.org/hnp/apa/d/t...  post id: 6464727698
# 12     https://minneapolis.craigslist.org/hnp/apa/d/o...  post id: 6464665890
# 13     https://minneapolis.craigslist.org/hnp/apa/d/n...  post id: 6464713513
# 14     https://minneapolis.craigslist.org/hnp/apa/d/l...  post id: 6464722884
# 15     https://minneapolis.craigslist.org/hnp/apa/d/s...  post id: 6459336225
# 16     https://minneapolis.craigslist.org/ram/apa/d/b...  post id: 6464720573
# 17     https://minneapolis.craigslist.org/dak/apa/d/p...  post id: 6457092923
# 18     https://minneapolis.craigslist.org/hnp/apa/d/a...  post id: 6464719755
# 19     https://minneapolis.craigslist.org/hnp/apa/d/p...  post id: 6464714849
# 20     https://minneapolis.craigslist.org/hnp/apa/d/3...  post id: 6447492667
# 21     https://minneapolis.craigslist.org/wsh/apa/d/s...  post id: 6464705288
# 22     https://minneapolis.craigslist.org/hnp/apa/d/1...  post id: 6464717459
# 23     https://minneapolis.craigslist.org/hnp/apa/d/o...  post id: 6464657214
# 24     https://minneapolis.craigslist.org/hnp/apa/d/h...  post id: 6457559543
# 25     https://minneapolis.craigslist.org/hnp/apa/d/1...  post id: 6464715108
# 26     https://minneapolis.craigslist.org/hnp/apa/d/1...  post id: 6464713847
# 27     https://minneapolis.craigslist.org/hnp/apa/d/b...  post id: 6464678516
# 28     https://minneapolis.craigslist.org/hnp/apa/d/n...  post id: 6464712674
# 29     https://minneapolis.craigslist.org/hnp/apa/d/c...  post id: 6464712523
# ...                                                  ...                  ...
# 77286  https://minneapolis.craigslist.org/ank/apa/d/r...  post id: 6523552898
# 77288  https://minneapolis.craigslist.org/hnp/apa/d/f...  post id: 6523551915
# 77289  https://minneapolis.craigslist.org/hnp/apa/d/w...  post id: 6523541725
# 77290  https://minneapolis.craigslist.org/ram/apa/d/w...  post id: 6523549744
# 77292  https://minneapolis.craigslist.org/hnp/apa/d/b...  post id: 6521028185
# 77293  https://minneapolis.craigslist.org/ank/apa/d/c...  post id: 6523546330
# 77294  https://minneapolis.craigslist.org/hnp/apa/d/n...  post id: 6523546146
# 77295  https://minneapolis.craigslist.org/ram/apa/d/c...  post id: 6523545824
# 77296  https://minneapolis.craigslist.org/hnp/apa/d/l...  post id: 6523545293
# 77297  https://minneapolis.craigslist.org/ram/apa/d/b...  post id: 6523542457
# 77299  https://minneapolis.craigslist.org/hnp/apa/d/r...  post id: 6523458746
# 77300  https://minneapolis.craigslist.org/hnp/apa/d/1...  post id: 6523538238
# 77301  https://minneapolis.craigslist.org/hnp/apa/d/c...  post id: 6523538241
# 77304  https://minneapolis.craigslist.org/ram/apa/d/t...  post id: 6523536371
# 77307  https://minneapolis.craigslist.org/hnp/apa/d/y...  post id: 6523535505
# 77308  https://minneapolis.craigslist.org/ram/apa/d/t...  post id: 6523535026
# 77309  https://minneapolis.craigslist.org/ram/apa/d/t...  post id: 6523533511
# 77310  https://minneapolis.craigslist.org/hnp/apa/d/c...  post id: 6523507356
# 77311  https://minneapolis.craigslist.org/hnp/apa/d/h...  post id: 6523533127
# 77312  https://minneapolis.craigslist.org/ram/apa/d/s...  post id: 6523530690
# 77315  https://minneapolis.craigslist.org/hnp/apa/d/t...  post id: 6523523380
# 77318  https://minneapolis.craigslist.org/hnp/apa/d/t...  post id: 6523521824
# 77320  https://minneapolis.craigslist.org/hnp/apa/d/s...  post id: 6523520893
# 77326  https://minneapolis.craigslist.org/ank/apa/d/c...  post id: 6523518342
# 77329  https://minneapolis.craigslist.org/hnp/apa/d/2...  post id: 6523515843
# 77330  https://minneapolis.craigslist.org/wsh/apa/d/1...  post id: 6523484717
# 77331  https://minneapolis.craigslist.org/ank/apa/d/l...  post id: 6523514028
# 77333  https://minneapolis.craigslist.org/hnp/apa/d/1...  post id: 6523512912
# 77457  https://minneapolis.craigslist.org/hnp/apa/d/2...  post id: 6523427282
# 77458  https://minneapolis.craigslist.org/dak/apa/d/s...  post id: 6523426971
#
#       value_square_feet_two     ...      check_superbowl address_check  \
# index                           ...
# 0                        []     ...                False         False
# 1                        []     ...                False          True
# 2                        []     ...                False         False
# 3                     688ft     ...                False          True
# 4                        []     ...                False         False
# 5                        []     ...                False         False
# 6                        []     ...                False         False
# 7                        []     ...                False         False
# 8                     950ft     ...                False          True
# 9                        []     ...                False         False
# 10                    789ft     ...                False          True
# 11                   1528ft     ...                False          True
# 12                    720ft     ...                False          True
# 13                    800ft     ...                False          True
# 14                    650ft     ...                False          True
# 15                   1200ft     ...                False          True
# 16                   1181ft     ...                False          True
# 17                       []     ...                False         False
# 18                       []     ...                False         False
# 19                       []     ...                False         False
# 20                   1120ft     ...                False          True
# 21                    849ft     ...                False          True
# 22                    696ft     ...                False         False
# 23                       []     ...                False         False
# 24                    980ft     ...                False          True
# 25                       []     ...                False         False
# 26                    820ft     ...                False          True
# 27                    739ft     ...                False          True
# 28                   1580ft     ...                False          True
# 29                    541ft     ...                False          True
# ...                     ...     ...                  ...           ...
# 77286                 575ft     ...                False          True
# 77288                1588ft     ...                False          True
# 77289                 970ft     ...                False          True
# 77290                 849ft     ...                False          True
# 77292                1012ft     ...                False          True
# 77293                1000ft     ...                False          True
# 77294                1308ft     ...                False          True
# 77295                 662ft     ...                False          True
# 77296                 900ft     ...                False          True
# 77297                1193ft     ...                False          True
# 77299                    []     ...                False         False
# 77300                 700ft     ...                False          True
# 77301                 847ft     ...                False         False
# 77304                 780ft     ...                False          True
# 77307                 517ft     ...                False          True
# 77308                 915ft     ...                False          True
# 77309                    []     ...                False          True
# 77310                    []     ...                False         False
# 77311                 700ft     ...                False          True
# 77312                    []     ...                False         False
# 77315                 700ft     ...                False          True
# 77318                 805ft     ...                False          True
# 77320                 700ft     ...                False          True
# 77326                1019ft     ...                False          True
# 77329                1000ft     ...                False          True
# 77330                 600ft     ...                False         False
# 77331                 800ft     ...                False          True
# 77333                 910ft     ...                False          True
# 77457                    []     ...                False         False
# 77458                1600ft     ...                False         False
#
#        county  address_lat  address_lon  county_lat  county_lon  \
# index
# 0         hnp          hnp          hnp     45.0209    -93.5095
# 1         hnp          hnp          hnp         NaN         NaN
# 2         hnp          hnp          hnp     45.0209    -93.5095
# 3         hnp          hnp          hnp         NaN         NaN
# 4         hnp          hnp          hnp     45.0209    -93.5095
# 5         hnp          hnp          hnp     45.0209    -93.5095
# 6         hnp          hnp          hnp     45.0209    -93.5095
# 7         hnp          hnp          hnp     45.0209    -93.5095
# 8         hnp          hnp          hnp         NaN         NaN
# 9         wsh          wsh          wsh     44.8897    -92.8577
# 10        hnp          hnp          hnp         NaN         NaN
# 11        hnp          hnp          hnp         NaN         NaN
# 12        hnp          hnp          hnp         NaN         NaN
# 13        hnp          hnp          hnp         NaN         NaN
# 14        hnp          hnp          hnp         NaN         NaN
# 15        hnp          hnp          hnp         NaN         NaN
# 16        ram          ram          ram         NaN         NaN
# 17        dak          dak          dak     44.7316    -93.1780
# 18        hnp          hnp          hnp     45.0209    -93.5095
# 19        hnp          hnp          hnp     45.0209    -93.5095
# 20        hnp          hnp          hnp         NaN         NaN
# 21        wsh          wsh          wsh         NaN         NaN
# 22        hnp          hnp          hnp     45.0209    -93.5095
# 23        hnp          hnp          hnp     45.0209    -93.5095
# 24        hnp          hnp          hnp         NaN         NaN
# 25        hnp          hnp          hnp     45.0209    -93.5095
# 26        hnp          hnp          hnp         NaN         NaN
# 27        hnp          hnp          hnp         NaN         NaN
# 28        hnp          hnp          hnp         NaN         NaN
# 29        hnp          hnp          hnp         NaN         NaN
# ...       ...          ...          ...         ...         ...
# 77286     ank          ank          ank         NaN         NaN
# 77288     hnp          hnp          hnp         NaN         NaN
# 77289     hnp          hnp          hnp         NaN         NaN
# 77290     ram          ram          ram         NaN         NaN
# 77292     hnp          hnp          hnp         NaN         NaN
# 77293     ank          ank          ank         NaN         NaN
# 77294     hnp          hnp          hnp         NaN         NaN
# 77295     ram          ram          ram         NaN         NaN
# 77296     hnp          hnp          hnp         NaN         NaN
# 77297     ram          ram          ram         NaN         NaN
# 77299     hnp          hnp          hnp     45.0209    -93.5095
# 77300     hnp          hnp          hnp         NaN         NaN
# 77301     hnp          hnp          hnp     45.0209    -93.5095
# 77304     ram          ram          ram         NaN         NaN
# 77307     hnp          hnp          hnp         NaN         NaN
# 77308     ram          ram          ram         NaN         NaN
# 77309     ram          ram          ram         NaN         NaN
# 77310     hnp          hnp          hnp     45.0209    -93.5095
# 77311     hnp          hnp          hnp         NaN         NaN
# 77312     ram          ram          ram     44.9964    -93.0616
# 77315     hnp          hnp          hnp         NaN         NaN
# 77318     hnp          hnp          hnp         NaN         NaN
# 77320     hnp          hnp          hnp         NaN         NaN
# 77326     ank          ank          ank         NaN         NaN
# 77329     hnp          hnp          hnp         NaN         NaN
# 77330     wsh          wsh          wsh     44.8897    -92.8577
# 77331     ank          ank          ank         NaN         NaN
# 77333     hnp          hnp          hnp         NaN         NaN
# 77457     hnp          hnp          hnp     45.0209    -93.5095
# 77458     dak          dak          dak     44.7316    -93.1780
#
#                          county_state  geocode_lat  geocode_lon
# index
# 0         ,Hennepin County, Minnesota         none         none
# 1         ,Hennepin County, Minnesota         none         none
# 2         ,Hennepin County, Minnesota         none         none
# 3         ,Hennepin County, Minnesota         none         none
# 4         ,Hennepin County, Minnesota         none         none
# 5         ,Hennepin County, Minnesota         none         none
# 6         ,Hennepin County, Minnesota         none         none
# 7         ,Hennepin County, Minnesota         none         none
# 8         ,Hennepin County, Minnesota         none         none
# 9       ,Washington County, Minnesota         none         none
# 10        ,Hennepin County, Minnesota         none         none
# 11        ,Hennepin County, Minnesota         none         none
# 12        ,Hennepin County, Minnesota         none         none
# 13        ,Hennepin County, Minnesota         none         none
# 14        ,Hennepin County, Minnesota         none         none
# 15        ,Hennepin County, Minnesota         none         none
# 16          ,Ramsey County, Minnesota         none         none
# 17          ,Dakota County, Minnesota         none         none
# 18        ,Hennepin County, Minnesota         none         none
# 19        ,Hennepin County, Minnesota         none         none
# 20        ,Hennepin County, Minnesota         none         none
# 21      ,Washington County, Minnesota         none         none
# 22        ,Hennepin County, Minnesota         none         none
# 23        ,Hennepin County, Minnesota         none         none
# 24        ,Hennepin County, Minnesota         none         none
# 25        ,Hennepin County, Minnesota         none         none
# 26        ,Hennepin County, Minnesota         none         none
# 27        ,Hennepin County, Minnesota         none         none
# 28        ,Hennepin County, Minnesota         none         none
# 29        ,Hennepin County, Minnesota         none         none
# ...                               ...          ...          ...
# 77286        ,Anoka County, Minnesota         none         none
# 77288     ,Hennepin County, Minnesota         none         none
# 77289     ,Hennepin County, Minnesota         none         none
# 77290       ,Ramsey County, Minnesota         none         none
# 77292     ,Hennepin County, Minnesota         none         none
# 77293        ,Anoka County, Minnesota         none         none
# 77294     ,Hennepin County, Minnesota         none         none
# 77295       ,Ramsey County, Minnesota         none         none
# 77296     ,Hennepin County, Minnesota         none         none
# 77297       ,Ramsey County, Minnesota         none         none
# 77299     ,Hennepin County, Minnesota         none         none
# 77300     ,Hennepin County, Minnesota         none         none
# 77301     ,Hennepin County, Minnesota         none         none
# 77304       ,Ramsey County, Minnesota         none         none
# 77307     ,Hennepin County, Minnesota         none         none
# 77308       ,Ramsey County, Minnesota         none         none
# 77309       ,Ramsey County, Minnesota         none         none
# 77310     ,Hennepin County, Minnesota         none         none
# 77311     ,Hennepin County, Minnesota         none         none
# 77312       ,Ramsey County, Minnesota         none         none
# 77315     ,Hennepin County, Minnesota         none         none
# 77318     ,Hennepin County, Minnesota         none         none
# 77320     ,Hennepin County, Minnesota         none         none
# 77326        ,Anoka County, Minnesota         none         none
# 77329     ,Hennepin County, Minnesota         none         none
# 77330   ,Washington County, Minnesota         none         none
# 77331        ,Anoka County, Minnesota         none         none
# 77333     ,Hennepin County, Minnesota         none         none
# 77457     ,Hennepin County, Minnesota         none         none
# 77458       ,Dakota County, Minnesota         none         none
#
# [34330 rows x 30 columns]

# %% [markdown]
# MERGE DATA AFTER GEOCODING

# %%
# pandas to work with dataframes
import pandas as pd
# import re to use regular expressions
import re
# import numpy
import numpy as np
# import glob to bring together multiple csv files
import glob

# search for csvs containing web-scraped data with the name scheme
csvs = glob.glob(r'*geocode_craigslist*.csv')

# set dfs list to store each dataframe that gets read in
dfs = []

# iterate through csv files gathered in glob
for file in csvs:
    # read each csv as a dataframe with the same column names
    df1 = pd.read_csv(file)
    # append dataframe to dfs list
    dfs.append(df1)

# concatenate dataframes in dfs together vertically
df = pd.concat(dfs, axis=0)
# set an index of integers equal to the length of dataframe rows
index_list = list(range(len(df.index)))
# make index series a column in dataframe
df['index'] = index_list
# set index column as index of dataframe
df = df.set_index(['index'])

# set entire df type as string, as most operations will require data type to be string
df = df.astype(str)


#mask dataframe to exclude values greater than 10000 and lower than 50
# convert price column to float
df['price'] = df['price'].astype(float)
# mask dataframe for values in "price" column greater than 10000
mask = df['price'] < 10000
df = df[mask]
# mask dataframe for values in "price" column greater than 50
mask = df['price'] > 50
df = df[mask]

# create a dataframe absent null or non-desirable values in the 
# "square feet", "beds_baths" and "price" columns
df2 = df.drop(df[(df['square feet boolean'] == 0) | (df['beds boolean'] == 0) | (df['price boolean'] == 0)].index)
# transform columns to numeric types so as to perform 
# mean operations
df2['price'] = pd.to_numeric(df2.price)
df2['square feet'] = pd.to_numeric(df2['square feet'])
df2['beds_baths'] = pd.to_numeric(df2['beds_baths'])
# get mean value of each column
price_mean = df2['price'].mean()
sqrft_mean = df2['square feet'].mean()
beds_mean = df2['beds_baths'].mean()
# for the "price", "beds_baths", "square feet" columns,
# set all non-matching values as the mean of each column
df.loc[(df['price boolean'] == 0), 'price'] = str(round(price_mean, 2))
df.loc[(df['beds boolean'] == 0), 'beds_baths'] = str(round(beds_mean, 2))
df.loc[(df['square feet boolean'] == 0), 'square feet'] = str(round(sqrft_mean, 2))


df.to_csv('craigslist_final_data')

# %% [markdown]
# GEOCODING SCRIPT

# %%
import googlemaps
from datetime import datetime
import pandas as pd
from IPython.core.display import clear_output
from random import randint
from time import time 
import requests
from requests import get
from warnings import warn 
from bs4 import BeautifulSoup
from IPython.core.display import clear_output
from time import sleep

from itertools import islice
csv = "geocode_craigslist_rentals.csv"

  

df = pd.read_csv(csv)

index_list = list(range(len(df.index)))
df['index'] = index_list

df = df.set_index(['index'])


sort df by address_check true false


for index, row in islice(df.iterrows(),2302, 3802):
    if (row['geocode_lat'] == "none") & (row['geocode_lon'] == "none") & (row['address_check'] == 1):
        

    

        try:

            sleep((2))
            gmaps = googlemaps.Client(key='AIzaSyDS4IF8J8x49OSMgGNAKloMvNdudswac1U')
            address = str(row['address'])
            geocode_result = gmaps.geocode(address)
            latitude = geocode_result[0]['geometry']['location']['lat']
            longitude = geocode_result[0]['geometry']['location']['lng'] 
            df.loc[index, "geocode_lon"] = str(longitude)
            df.loc[index, "geocode_lat"] = str(latitude)
            if (count %50 ==0):
                print (row['geocode_lon'], row['address'])
            count += 1
            print ('Request: {}'.format(count))
            clear_output(wait = True)


        except:
            if (count %50 ==0):
                print (row['geocode_lon'], row['address'])

            df.loc[index, "geocode_lon"] = "error"
            df.loc[index, "geocode_lat"] = "error"


            count += 1
            print ('Request: {}'.format(count))
            clear_output(wait = True)


       


    
df.to_csv('geocode_craigslist_rentals.csv', header=True)
